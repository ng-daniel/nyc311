# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("sample2.csv").iloc[:, 1:]
df.head()
# Out:
# C:\Users\ng17d\AppData\Local\Temp\ipykernel_40032\2212629416.py:1: DtypeWarning: Columns (0: vehicle_type, 1: taxi_company_borough, 2: due_date) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("sample2.csv").iloc[:, 1:]
#    unique_key             created_date              closed_date agency  \
# 0    52398898  2021-11-02T05:53:14.000  2021-11-03T17:47:09.000    HPD
# 1    52393238  2021-11-02T10:46:30.000  2021-11-05T16:39:35.000    HPD
# 2    52400431  2021-11-02T11:09:55.000  2021-11-04T00:00:00.000    DOB
# 3    52392864  2021-11-02T11:35:08.000  2021-11-02T14:11:54.000   NYPD
# 4    52392330  2021-11-02T19:49:48.000  2021-11-29T07:04:21.000    HPD
#
#                                          agency_name  \
# 0  Department of Housing Preservation and Develop...
# 1  Department of Housing Preservation and Develop...
# 2                            Department of Buildings
# 3                    New York City Police Department
# 4  Department of Housing Preservation and Develop...
#
#                   complaint_type  \
# 0                 HEAT/HOT WATER
# 1                 HEAT/HOT WATER
# 2  General Construction/Plumbing
# 3                Illegal Parking
# 4           UNSANITARY CONDITION
#
#                                       descriptor  descriptor_2  \
# 0                                ENTIRE BUILDING       NO HEAT
# 1                                 APARTMENT ONLY  NO HOT WATER
# 2  Cons - Contrary/Beyond Approved Plans/Permits           NaN
# 3                                Blocked Hydrant           NaN
# 4                                           MOLD           NaN
#
#           location_type  incident_zip        incident_address  \
# 0  RESIDENTIAL BUILDING       10466.0  3928 MONTICELLO AVENUE
# 1  RESIDENTIAL BUILDING       11208.0         458 RUBY STREET
# 2                   NaN       10009.0            204 AVENUE A
# 3       Street/Sidewalk       11366.0        77-45 160 STREET
# 4  RESIDENTIAL BUILDING       11217.0      46 ST FELIX STREET
#
#          street_name address_type           city  status  \
# 0  MONTICELLO AVENUE      ADDRESS          BRONX  Closed
# 1        RUBY STREET      ADDRESS       BROOKLYN  Closed
# 2           AVENUE A      ADDRESS       NEW YORK  Closed
# 3         160 STREET      ADDRESS  FRESH MEADOWS  Closed
# 4    ST FELIX STREET      ADDRESS       BROOKLYN  Closed
#
#                               resolution_description  \
# 0  The Department of Housing Preservation and Dev...
# 1  The complaint you filed is a duplicate of a co...
# 2  The Department of Buildings investigated this ...
# 3  The Police Department responded to the complai...
# 4  The Department of Housing Preservation and Dev...
#
#   resolution_action_updated_date community_board  council_district  \
# 0        2021-11-03T00:00:00.000        12 BRONX              12.0
# 1        2021-11-05T00:00:00.000     05 BROOKLYN              42.0
# 2        2021-11-04T00:00:00.000    03 MANHATTAN               2.0
# 3        2021-11-02T14:11:57.000       08 QUEENS              24.0
# 4        2021-11-29T00:00:00.000     02 BROOKLYN              35.0
#
#   police_precinct           bbl    borough  x_coordinate_state_plane  \
# 0     Precinct 47  2.049600e+09      BRONX                 1029144.0
# 1     Precinct 75  3.044710e+09   BROOKLYN                 1022991.0
# 2      Precinct 9  1.004060e+09  MANHATTAN                  989516.0
# 3    Precinct 107  4.068390e+09     QUEENS                 1037472.0
# 4     Precinct 88  3.020960e+09   BROOKLYN                  990432.0
#
#    y_coordinate_state_plane open_data_channel_type park_facility_name  \
# 0                  263417.0                  PHONE        Unspecified
# 1                  183785.0                  PHONE        Unspecified
# 2                  205058.0                UNKNOWN        Unspecified
# 3                  202752.0                 ONLINE        Unspecified
# 4                  190141.0                 ONLINE        Unspecified
#
#   park_borough   latitude  longitude  \
# 0        BRONX  40.889579 -73.837630
# 1     BROOKLYN  40.671039 -73.860343
# 2    MANHATTAN  40.729512 -73.981000
# 3       QUEENS  40.723024 -73.807991
# 4     BROOKLYN  40.688568 -73.977709
#
#                                             location cross_street_1  \
# 0  {'type': 'Point', 'coordinates': [-73.83763012...            NaN
# 1  {'type': 'Point', 'coordinates': [-73.86034305...            NaN
# 2  {'type': 'Point', 'coordinates': [-73.98100001...            NaN
# 3  {'type': 'Point', 'coordinates': [-73.80799094...        77 ROAD
# 4  {'type': 'Point', 'coordinates': [-73.97770873...            NaN
#
#   cross_street_2 intersection_street_1 intersection_street_2    landmark  \
# 0            NaN                   NaN                   NaN         NaN
# 1            NaN                   NaN                   NaN         NaN
# 2            NaN                   NaN                   NaN         NaN
# 3      78 AVENUE               77 ROAD             78 AVENUE  160 STREET
# 4            NaN                   NaN                   NaN         NaN
#
#   facility_type bridge_highway_name bridge_highway_segment  \
# 0           NaN                 NaN                    NaN
# 1           NaN                 NaN                    NaN
# 2           NaN                 NaN                    NaN
# 3           NaN                 NaN                    NaN
# 4           NaN                 NaN                    NaN
#
#   taxi_pick_up_location bridge_highway_direction road_ramp vehicle_type  \
# 0                   NaN                      NaN       NaN          NaN
# 1                   NaN                      NaN       NaN          NaN
# 2                   NaN                      NaN       NaN          NaN
# 3                   NaN                      NaN       NaN          NaN
# 4                   NaN                      NaN       NaN          NaN
#
#   taxi_company_borough due_date
# 0                  NaN      NaN
# 1                  NaN      NaN
# 2                  NaN      NaN
# 3                  NaN      NaN
# 4                  NaN      NaN

# %%
print(df.columns)
# Out:
# Index(['unique_key', 'created_date', 'closed_date', 'agency', 'agency_name',
#        'complaint_type', 'descriptor', 'descriptor_2', 'location_type',
#        'incident_zip', 'incident_address', 'street_name', 'address_type',
#        'city', 'status', 'resolution_description',
#        'resolution_action_updated_date', 'community_board', 'council_district',
#        'police_precinct', 'bbl', 'borough', 'x_coordinate_state_plane',
#        'y_coordinate_state_plane', 'open_data_channel_type',
#        'park_facility_name', 'park_borough', 'latitude', 'longitude',
#        'location', 'cross_street_1', 'cross_street_2', 'intersection_street_1',
#        'intersection_street_2', 'landmark', 'facility_type',
#        'bridge_highway_name', 'bridge_highway_segment',
#        'taxi_pick_up_location', 'bridge_highway_direction', 'road_ramp',
#        'vehicle_type', 'taxi_company_borough', 'due_date'],
#       dtype='str')

# %%
import time

def striptime(x):
    try:
        return pd.to_datetime(x)
    except:
        return x

new_df = df.filter(["closed_date", "created_date"]).dropna(axis=0)
closed_date = pd.to_datetime(new_df.closed_date)
created_date = pd.to_datetime(new_df.created_date)
print(closed_date.head())
diff = closed_date - created_date
print(diff.idxmin(), diff.min())
closed_date[diff.idxmin()], created_date[diff.idxmin()]
# Out:
# 0   2021-11-03 17:47:09
# 1   2021-11-05 16:39:35
# 2   2021-11-04 00:00:00
# 3   2021-11-02 14:11:54
# 4   2021-11-29 07:04:21
# Name: closed_date, dtype: datetime64[us]
# 2405 -114 days +23:59:00
# (Timestamp('2021-07-13 10:25:00'), Timestamp('2021-11-03 10:26:00'))

# %%
agency_cts = df.agency.value_counts()
complaint_cts = df.complaint_type.value_counts()
print(agency_cts, complaint_cts)
# Out:
# agency
# NYPD     37560
# HPD      26544
# DSNY     13981
# DOT       5704
# DEP       4458
# DOB       2577
# DOHMH     2499
# DPR       2480
# DHS       1877
# TLC        811
# EDC        771
# DCWP       596
# OSE         80
# DOE         43
# DFTA        10
# DOITT        9
# Name: count, dtype: int64 complaint_type
# HEAT/HOT WATER                         13098
# Illegal Parking                        11430
# Noise - Residential                     8858
# Request Large Bulky Item Collection     7051
# Blocked Driveway                        5288
#                                        ...
# Overflowing Litter Baskets                 1
# DEP Street Condition                       1
# Mosquitoes                                 1
# Vacant Lot                                 1
# Food Poisoning                             1
# Name: count, Length: 165, dtype: int64

# %%
location_df = df.filter(['latitude','longitude'])
location_df.isna().value_counts()
# Out:
# latitude  longitude
# False     False        983
# True      True          17
# Name: count, dtype: int64

# %%
df.groupby(['borough']).complaint_type.value_counts().reset_index()
# Out:
#    borough                           complaint_type  count
# 0   QUEENS                       Indoor Air Quality    369
# 1   QUEENS                           Food Poisoning    128
# 2   QUEENS                 Traffic Signal Condition     85
# 3   QUEENS                             Building/Use     60
# 4   QUEENS                     UNSANITARY CONDITION     40
# 5   QUEENS                       Noise - Helicopter     32
# 6   QUEENS                           Taxi Complaint     26
# 7   QUEENS                                 Asbestos     22
# 8   QUEENS                          Dead/Dying Tree     21
# 9   QUEENS                            PAINT/PLASTER     17
# 10  QUEENS                                 PLUMBING     17
# 11  QUEENS            General Construction/Plumbing     16
# 12  QUEENS                                     Mold     16
# 13  QUEENS                                  GENERAL     15
# 14  QUEENS                             Damaged Tree     15
# 15  QUEENS                                APPLIANCE     11
# 16  QUEENS                  Overgrown Tree/Branches     11
# 17  QUEENS                               WATER LEAK      9
# 18  QUEENS                   Street Light Condition      9
# 19  QUEENS               For Hire Vehicle Complaint      9
# 20  QUEENS                                   SAFETY      8
# 21  QUEENS                              DOOR/WINDOW      6
# 22  QUEENS                      Illegal Tree Damage      6
# 23  QUEENS                                 ELECTRIC      5
# 24  QUEENS      Request Large Bulky Item Collection      5
# 25  QUEENS  Special Projects Inspection Team (SPIT)      5
# 26  QUEENS                           Uprooted Stump      4
# 27  QUEENS                  Maintenance or Facility      4
# 28  QUEENS                          FLOORING/STAIRS      3
# 29  QUEENS                           HEAT/HOT WATER      3
# 30  QUEENS                    Street Sign - Missing      3
# 31  QUEENS                                 Plumbing      2
# 32  QUEENS            Root/Sewer/Sidewalk Condition      2
# 33  QUEENS                                    Sewer      2
# 34  QUEENS                               Electrical      1
# 35  QUEENS                                 Elevator      1
# 36  QUEENS                    Street Sign - Damaged      1
# 37  QUEENS                       Sidewalk Condition      1
# 38  QUEENS                                 ELEVATOR      1
# 39  QUEENS                     Green Taxi Complaint      1
# 40  QUEENS                                   Rodent      1
# 41  QUEENS            Emergency Response Team (ERT)      1
# 42  QUEENS                         Dirty Conditions      1
# 43  QUEENS               Homeless Person Assistance      1
# 44  QUEENS                             Water System      1
# 45  QUEENS                     Sanitation Condition      1
# 46  QUEENS                       School Maintenance      1
# 47  QUEENS                      Wood Pile Remaining      1
